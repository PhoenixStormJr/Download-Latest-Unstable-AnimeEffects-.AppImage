# %% [markdown]
# <a href="https://colab.research.google.com/github/PhoenixStormJr/Download-Latest-Unstable-AnimeEffects-.AppImage/blob/main/Download_Latest_Unstable_Anime_Effects_Appimage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Check out the official repository here:
# https://github.com/AnimeEffectsDevs/AnimeEffects/
#
# Check out latest stable release here:
# https://github.com/AnimeEffectsDevs/AnimeEffects/releases/
#
# Donate (to help the developers create more features) here:
# https://liberapay.com/AnimeEffects

# %%
# @title Run this cell to download the latest (and unstable) version of AnimeEffects .AppImage (23 minutes)
import os
from google.colab import files
import datetime

StartTime = datetime.datetime.now()
# Update apt and install dependencies
# !apt update && sudo apt upgrade -y
# !sudo apt install -y software-properties-common g++ make cmake ninja-build wget rsync build-essential libglib2.0-0
# !sudo apt install -y libgl1-mesa-dev file libvulkan-dev openssl python3 python3-pip libxcb-cursor0 libxrandr2 wget

#Here are my NEW apt installations:
# !apt install -y git libtool autoconf pkg-config libssl-dev libxkbcommon-dev libx11-dev libxkbcommon-x11-0 libxcb-icccm4 libxcb-icccm4-dev libxcb-xfixes0 libxcb-xfixes0-dev libxcb-keysyms1 libxcb-keysyms1-dev gstreamer1.0-gl gstreamer1.0-plugins-base gstreamer1.0-plugins-good gstreamer1.0-plugins-bad gstreamer1.0-plugins-ugly

#Back to original code:
# !pip install -U pip
# !pip install aqtinstall
# !aqt install-qt linux desktop 6.6.2 gcc_64 -m qtimageformats qtmultimedia qt5compat
# !git clone https://github.com/AnimeEffectsDevs/AnimeEffects.git
# %cd AnimeEffects

#Added this line to run cmake and other stuff easily:
os.environ['PATH'] += ':/content/6.6.2/gcc_64/bin'

#Original:
# !cmake -S . -B build -G "Ninja Multi-Config"
# !cmake --build build --config Release
# %cd build/src/gui/Release
# !mkdir -p appdir
# !cp AnimeEffects appdir
# !cp -R ../data appdir/data
# !cp -R ../../../../dist appdir/dist
# !cp ../../../../dist/AnimeEffects.png appdir
# !find appdir/
# !export APPIMAGE_EXTRACT_AND_RUN=1
# !wget -c -nv "https://github.com/p-yukusai/linuxdeployqt/releases/download/continuous/linuxdeployqt-continuous-x86_64.AppImage"
# !chmod a+x linuxdeployqt-continuous-x86_64.AppImage
# !./linuxdeployqt-continuous-x86_64.AppImage appdir/dist/AnimeEffects.desktop -extra-plugins=imageformats,multimedia,core5compat -appimage -verbose=2

#MyCode to find the .AppImage and rename it:
AnimeEffectsFile = ""
for MyFile in os.listdir('/content/AnimeEffects/build/src/gui/Release'):
  if ('AnimeEffects' in MyFile and '.AppImage' in MyFile):
    AnimeEffectsFile = '/content/AnimeEffects/build/src/gui/Release/' + MyFile
os.rename(AnimeEffectsFile, "/content/AnimeEffects/build/src/gui/Release/AnimeEffects-Latest-Unstable-x86_64.AppImage")
AnimeEffectsFile = "/content/AnimeEffects/build/src/gui/Release/AnimeEffects-Latest-Unstable-x86_64.AppImage"

#Original again, but edited to include the REAL .AppImage
# !chmod a+x {AnimeEffectsFile}
#Download the .AppImage to your linux computer:
files.download(AnimeEffectsFile)

#Print how long it took
EndTime = datetime.datetime.now()
time_elapsed = EndTime - StartTime
print(f"Started: {StartTime.strftime('%I:%M %p')}")
print(f"Ended: {EndTime.strftime('%I:%M %p')}")
print(f"Total time elapsed: {time_elapsed}")
# Out:
# Streaming output truncated to the last 5000 lines.
# [81/263] Building CXX object src/core/CMakeFiles/core.dir/Release/BoneShape.cpp.o
# /content/AnimeEffects/src/core/BoneShape.cpp: In function ‘QPolygonF core::objToPoly(QJsonObject, QString)’:
# /content/AnimeEffects/src/core/BoneShape.cpp:368:33: warning: ‘constexpr typename std::add_const<_Tp>::type& qAsConst(T&) [with T = QJsonArray; typename std::add_const<_Tp>::type = const QJsonArray]’ is deprecated: Use std::as_const() instead. [-Wdeprecated-declarations]
#   368 |         for (auto vtx : qAsConst(polyArray)) {
#       |                         ~~~~~~~~^~~~~~~~~~~
# In file included from /content/6.6.2/gcc_64/include/QtCore/qforeach.h:11,
#                  from /content/6.6.2/gcc_64/include/QtCore/qglobal.h:57,
#                  from /content/6.6.2/gcc_64/include/QtCore/qmath.h:11,
#                  from /content/6.6.2/gcc_64/include/QtCore/QtMath:1,
#                  from /content/AnimeEffects/src/core/BoneShape.cpp:1:
# ...
